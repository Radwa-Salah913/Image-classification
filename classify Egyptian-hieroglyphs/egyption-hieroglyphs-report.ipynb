# %%
import pandas as pd 
import numpy as np

# %%
models_name=['CNN','ResNet152','EfficientNetB2','NASNetMobile']

# %%
final_report=[0.23277729749679565,23.135332107543945,0.9588689208030701,0.010282776318490505,0.49742311239242554,0.6191306114196777,0.8589790463447571,0.791773796081543,0.6079710125923157,0.76915043592453,0.8351083397865295,0.7557840347290039,0.7884153723716736,0.812210738658905,0.7936099767684937,0.7712082266807556]
final_report = np.array(final_report).reshape(4,4)

# %%
model_accuracy=pd.DataFrame(final_report,index=models_name,columns=['Train Loss','Test Loss','Train Accuracy','Test Accuracy'])

# %%
model_accuracy.head()
# Out:
#                 Train Loss  Test Loss  Train Accuracy  Test Accuracy
# CNN               0.232777  23.135332        0.958869       0.010283
# ResNet152         0.497423   0.619131        0.858979       0.791774
# EfficientNetB2    0.607971   0.769150        0.835108       0.755784
# NASNetMobile      0.788415   0.812211        0.793610       0.771208

# %%
model_accuracy_reset = model_accuracy.reset_index()
print(model_accuracy_reset)
# Out:
#             index  Train Loss  Test Loss  Train Accuracy  Test Accuracy
# 0             CNN    0.232777  23.135332        0.958869       0.010283
# 1       ResNet152    0.497423   0.619131        0.858979       0.791774
# 2  EfficientNetB2    0.607971   0.769150        0.835108       0.755784
# 3    NASNetMobile    0.788415   0.812211        0.793610       0.771208

# %%
model_accuracy_reset.to_csv('Egyption_Hieroglyphs_Report.csv',index=False)
